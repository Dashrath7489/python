# %%
# Import all essential library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv(r"C:\Users\VICTUS\OneDrive\Desktop\Grow Stack Data Science\Datasets\manufacturing.csv")
data
# Out:
#       Temperature (°C)  Pressure (kPa)  Temperature x Pressure  \
# 0           209.762701        8.050855             1688.769167
# 1           243.037873       15.812068             3842.931469
# 2           220.552675        7.843130             1729.823314
# 3           208.976637       23.786089             4970.736918
# 4           184.730960       15.797812             2918.345014
# ...                ...             ...                     ...
# 3952        156.811578       21.794290             3417.596965
# 3953        197.850406        8.291704             1640.516924
# 3954        241.357144       16.391910             3956.304672
# 3955        209.040239       23.809936             4977.234763
# 3956        163.359996       24.332133             3974.897121
#
#       Material Fusion Metric  Material Transformation Metric  Quality Rating
# 0               44522.217074                    9.229576e+06       99.999971
# 1               63020.764997                    1.435537e+07       99.985703
# 2               49125.950249                    1.072839e+07       99.999758
# 3               57128.881547                    9.125702e+06       99.999975
# 4               38068.201283                    6.303792e+06      100.000000
# ...                      ...                             ...             ...
# 3952            34941.963896                    3.855501e+06      100.000000
# 3953            39714.857236                    7.744742e+06       99.999997
# 3954            62657.690952                    1.405957e+07       99.989318
# 3955            57195.985528                    9.134036e+06       99.999975
# 3956            41092.392901                    4.358913e+06      100.000000
#
# [3957 rows x 6 columns]

# %%
data.head()
# Out:
#    Temperature (°C)  Pressure (kPa)  Temperature x Pressure  \
# 0        209.762701        8.050855             1688.769167
# 1        243.037873       15.812068             3842.931469
# 2        220.552675        7.843130             1729.823314
# 3        208.976637       23.786089             4970.736918
# 4        184.730960       15.797812             2918.345014
#
#    Material Fusion Metric  Material Transformation Metric  Quality Rating
# 0            44522.217074                    9.229576e+06       99.999971
# 1            63020.764997                    1.435537e+07       99.985703
# 2            49125.950249                    1.072839e+07       99.999758
# 3            57128.881547                    9.125702e+06       99.999975
# 4            38068.201283                    6.303792e+06      100.000000

# %%
data.tail()
# Out:
#       Temperature (°C)  Pressure (kPa)  Temperature x Pressure  \
# 3952        156.811578       21.794290             3417.596965
# 3953        197.850406        8.291704             1640.516924
# 3954        241.357144       16.391910             3956.304672
# 3955        209.040239       23.809936             4977.234763
# 3956        163.359996       24.332133             3974.897121
#
#       Material Fusion Metric  Material Transformation Metric  Quality Rating
# 3952            34941.963896                    3.855501e+06      100.000000
# 3953            39714.857236                    7.744742e+06       99.999997
# 3954            62657.690952                    1.405957e+07       99.989318
# 3955            57195.985528                    9.134036e+06       99.999975
# 3956            41092.392901                    4.358913e+06      100.000000

# %%
data.describe()
# Out:
#        Temperature (°C)  Pressure (kPa)  Temperature x Pressure  \
# count       3957.000000     3957.000000             3957.000000
# mean         200.034704       14.815558             2955.321308
# std           58.135717        5.772040             1458.224940
# min          100.014490        5.003008              513.706875
# 25%          150.871296        9.692984             1798.247303
# 50%          198.603371       14.832557             2678.277782
# 75%          251.366552       19.749680             3929.058261
# max          299.992804       24.999132             7365.018714
#
#        Material Fusion Metric  Material Transformation Metric  Quality Rating
# count             3957.000000                    3.957000e+03     3957.000000
# mean             48127.183128                    1.003645e+07       96.260179
# std              23812.213513                    7.599356e+06       12.992262
# min              10156.971955                    9.999462e+05        1.000000
# 25%              27626.929091                    3.433810e+06       99.941129
# 50%              44611.452164                    7.833390e+06       99.999997
# 75%              67805.443846                    1.588251e+07      100.000000
# max             103756.181544                    2.699783e+07      100.000000

# %%
data.shape
# Out:
# (3957, 6)

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3957 entries, 0 to 3956
# Data columns (total 6 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Temperature (°C)                3957 non-null   float64
#  1   Pressure (kPa)                  3957 non-null   float64
#  2   Temperature x Pressure          3957 non-null   float64
#  3   Material Fusion Metric          3957 non-null   float64
#  4   Material Transformation Metric  3957 non-null   float64
#  5   Quality Rating                  3957 non-null   float64
# dtypes: float64(6)
# memory usage: 185.6 KB

# %%
data.isnull().sum()
# Out:
# Temperature (°C)                  0
# Pressure (kPa)                    0
# Temperature x Pressure            0
# Material Fusion Metric            0
# Material Transformation Metric    0
# Quality Rating                    0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
plt.figure(figsize = (4,3))
sns.scatterplot(x = data["Material Transformation Metric"], y = data["Quality Rating"])
sns.lineplot(x = data["Material Transformation Metric"], y = data["Quality Rating"], color = "red")
plt.xlabel("Material Transformation Metric")
plt.ylabel("Quality Rating")
plt.show()

# %%
data.columns
# Out:
# Index(['Temperature (°C)', 'Pressure (kPa)', 'Temperature x Pressure',
#        'Material Fusion Metric', 'Material Transformation Metric',
#        'Quality Rating'],
#       dtype='str')

# %%
col = ['Temperature (°C)', 'Pressure (kPa)', 'Temperature x Pressure',
       'Material Fusion Metric', 'Material Transformation Metric']
for i in col:
       plt.figure(figsize = (4,3))
       sns.scatterplot(x = data[i], y = data["Quality Rating"])
       plt.show()

# %%
x = data.iloc[:,:-1]
x
# Out:
#       Temperature (°C)  Pressure (kPa)  Temperature x Pressure  \
# 0           209.762701        8.050855             1688.769167
# 1           243.037873       15.812068             3842.931469
# 2           220.552675        7.843130             1729.823314
# 3           208.976637       23.786089             4970.736918
# 4           184.730960       15.797812             2918.345014
# ...                ...             ...                     ...
# 3952        156.811578       21.794290             3417.596965
# 3953        197.850406        8.291704             1640.516924
# 3954        241.357144       16.391910             3956.304672
# 3955        209.040239       23.809936             4977.234763
# 3956        163.359996       24.332133             3974.897121
#
#       Material Fusion Metric  Material Transformation Metric
# 0               44522.217074                    9.229576e+06
# 1               63020.764997                    1.435537e+07
# 2               49125.950249                    1.072839e+07
# 3               57128.881547                    9.125702e+06
# 4               38068.201283                    6.303792e+06
# ...                      ...                             ...
# 3952            34941.963896                    3.855501e+06
# 3953            39714.857236                    7.744742e+06
# 3954            62657.690952                    1.405957e+07
# 3955            57195.985528                    9.134036e+06
# 3956            41092.392901                    4.358913e+06
#
# [3957 rows x 5 columns]

# %%
y = data.iloc[:,-1]
y
# Out:
# 0        99.999971
# 1        99.985703
# 2        99.999758
# 3        99.999975
# 4       100.000000
#            ...
# 3952    100.000000
# 3953     99.999997
# 3954     99.989318
# 3955     99.999975
# 3956    100.000000
# Name: Quality Rating, Length: 3957, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size= 0.3)

# %%
print(x_train.shape,y_train.shape)
print(x_test.shape,y_test.shape)
# Out:
# (2769, 5) (2769,)
# (1188, 5) (1188,)

# %% [markdown]
# # Multiple Linear Regression

# %%
from sklearn.linear_model import LinearRegression
multi_model = LinearRegression()
multi_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
multi_pred = multi_model.predict(x_test)
multi_pred[:10]
# Out:
# array([102.01233314, 103.27920787,  95.27684807,  98.29033686,
#        101.60010533,  96.94025345,  72.43224009, 103.08097339,
#         94.37329876,  76.38385323])

# %%
y_test[:10]
# Out:
# 2329    100.000000
# 3105     99.999998
# 1824     99.961837
# 3157     99.989683
# 2508    100.000000
# 2199    100.000000
# 1802     59.707268
# 3665     99.999995
# 3007    100.000000
# 3601     69.422965
# Name: Quality Rating, dtype: float64

# %%
from sklearn.metrics import r2_score
r2_score(y_test,multi_pred)*100
# Out:
# 48.17581120842078

# %% [markdown]
# # polynomial Regression

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_feature = PolynomialFeatures()
x_poly = poly_feature.fit_transform(x)

# %%
x_poly[:5]
# Out:
# array([[1.00000000e+00, 2.09762701e+02, 8.05085537e+00, 1.68876917e+03,
#         4.45222171e+04, 9.22957596e+06, 4.40003906e+04, 1.68876917e+03,
#         3.54240781e+05, 9.33910050e+06, 1.93602078e+09, 6.48162722e+01,
#         1.35960363e+04, 3.58441931e+05, 7.43059812e+07, 2.85194130e+06,
#         7.51877474e+07, 1.55866233e+10, 1.98222781e+09, 4.10921184e+11,
#         8.51850724e+13],
#        [1.00000000e+00, 2.43037873e+02, 1.58120684e+01, 3.84293147e+03,
#         6.30207650e+04, 1.43553672e+07, 5.90674078e+04, 3.84293147e+03,
#         9.33977891e+05, 1.53164327e+07, 3.48889790e+09, 2.50021506e+02,
#         6.07646951e+04, 9.96488645e+05, 2.26988047e+08, 1.47681223e+07,
#         2.42184481e+08, 5.51666922e+10, 3.97161682e+09, 9.04686220e+11,
#         2.06076566e+14],
#        [1.00000000e+00, 2.20552675e+02, 7.84313005e+00, 1.72982331e+03,
#         4.91259502e+04, 1.07283887e+07, 4.86434825e+04, 1.72982331e+03,
#         3.81517159e+05, 1.08348597e+07, 2.36617483e+09, 6.15146889e+01,
#         1.35672292e+04, 3.85301216e+05, 8.41441477e+07, 2.99228870e+06,
#         8.49792140e+07, 1.85582169e+10, 2.41335899e+09, 5.27042289e+11,
#         1.15098324e+14],
#        [1.00000000e+00, 2.08976637e+02, 2.37860892e+01, 4.97073692e+03,
#         5.71288815e+04, 9.12570195e+06, 4.36712346e+04, 4.97073692e+03,
#         1.03876788e+06, 1.19386015e+07, 1.90705850e+09, 5.65778039e+02,
#         1.18234392e+05, 1.35887267e+06, 2.17064761e+08, 2.47082255e+07,
#         2.83972641e+08, 4.53614636e+10, 3.26370911e+09, 5.21341146e+11,
#         8.32784362e+13],
#        [1.00000000e+00, 1.84730960e+02, 1.57978122e+01, 2.91834501e+03,
#         3.80682013e+04, 6.30379189e+06, 3.41255275e+04, 2.91834501e+03,
#         5.39108676e+05, 7.03237536e+06, 1.16450553e+09, 2.49570871e+02,
#         4.61034665e+04, 6.01394295e+05, 9.95861204e+07, 8.51673762e+06,
#         1.11096145e+08, 1.83966396e+10, 1.44918795e+09, 2.39974018e+11,
#         3.97377921e+13]])

# %%
x_poly.shape
# Out:
# (3957, 21)

# %%
x_train,x_test,y_train,y_test = train_test_split(x_poly,y,test_size=0.3,)

# %%
print(x_train.shape,y_train.shape)
print(x_test.shape,y_test.shape)
# Out:
# (2769, 21) (2769,)
# (1188, 21) (1188,)

# %%
from sklearn.linear_model import LinearRegression
poly_model = LinearRegression()
poly_model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
poly_pred = poly_model.predict(x_test)
poly_pred[:10]
# Out:
# array([101.3588958 , 103.74300705,  33.304884  ,  59.00692823,
#         97.90492728,  98.25488285,  99.74449704,  97.75831835,
#        100.19400173, 102.19931437])

# %%
r2_score(y_test,poly_pred)
# Out:
# 0.8431866065260238
