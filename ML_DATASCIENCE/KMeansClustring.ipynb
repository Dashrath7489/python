# %%
print("KMeansClustring")
# Out:
# KMeansClustring

# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv(r"C:\Users\VICTUS\OneDrive\Desktop\Grow Stack Data Science\Datasets\Student_Performance.csv")

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
df.shape
# Out:
# (10000, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Hours Studied                     10000 non-null  int64
#  1   Previous Scores                   10000 non-null  int64
#  2   Extracurricular Activities        10000 non-null  object
#  3   Sleep Hours                       10000 non-null  int64
#  4   Sample Question Papers Practiced  10000 non-null  int64
#  5   Performance Index                 10000 non-null  float64
# dtypes: float64(1), int64(4), object(1)
# memory usage: 468.9+ KB

# %%
df.duplicated().sum()
# Out:
# np.int64(127)

# %%
df.drop_duplicates(inplace=True)

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              4               82                         No            4
# 2              8               51                        Yes            7
# 3              5               52                        Yes            5
# 4              7               75                         No            8
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 1               91.0
# 1                                 2               65.0
# 2                                 2               45.0
# 3                                 2               36.0
# 4                                 5               66.0

# %%
df["Extracurricular Activities"].value_counts()
# Out:
# Extracurricular Activities
# No     4986
# Yes    4887
# Name: count, dtype: int64

# %%
num_col = df.select_dtypes(include="number").columns
print(num_col)
# Out:
# Index(['Hours Studied', 'Previous Scores', 'Sleep Hours',
#        'Sample Question Papers Practiced', 'Performance Index'],
#       dtype='object')

# %%
from sklearn.preprocessing import StandardScaler
st_scale = StandardScaler()
num_col = ['Hours Studied', 'Previous Scores', 'Sleep Hours',
       'Sample Question Papers Practiced', 'Performance Index']
for i in num_col:
    df[i] = st_scale.fit_transform(df[[i]])

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0       0.775566         1.706168                        Yes     1.454025
# 1      -0.383205         0.724912                         No    -1.491315
# 2       1.161822        -1.064438                        Yes     0.275889
# 3       0.003052        -1.006717                        Yes    -0.902247
# 4       0.775566         0.320865                         No     0.864957
#
#    Sample Question Papers Practiced  Performance Index
# 0                         -1.249715           1.862979
# 1                         -0.900925           0.509348
# 2                         -0.900925          -0.531907
# 3                         -0.900925          -1.000471
# 4                          0.145444           0.561411

# %%
from sklearn.preprocessing import LabelEncoder
lab_enc = LabelEncoder()
df["Extracurricular Activities"] = lab_enc.fit_transform(df["Extracurricular Activities"])

# %%
df.head()
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0       0.775566         1.706168                           1     1.454025
# 1      -0.383205         0.724912                           0    -1.491315
# 2       1.161822        -1.064438                           1     0.275889
# 3       0.003052        -1.006717                           1    -0.902247
# 4       0.775566         0.320865                           0     0.864957
#
#    Sample Question Papers Practiced  Performance Index
# 0                         -1.249715           1.862979
# 1                         -0.900925           0.509348
# 2                         -0.900925          -0.531907
# 3                         -0.900925          -1.000471
# 4                          0.145444           0.561411

# %%
from sklearn.cluster import KMeans

wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init="k-means++")
    kmeans.fit(df)
    wcss.append(kmeans.inertia_)

# %%
wcss
# Out:
# [51833.001823154074,
#  37616.48126485872,
#  33386.26807108783,
#  29586.94777706159,
#  26733.31548266883,
#  24747.63478934807,
#  22886.43082716367,
#  20983.53346937074,
#  19838.043534651537,
#  18814.417394456275]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(3,2))
plt.plot(range(1,11),wcss)
plt .show()

# %%
kmeans = KMeans(n_clusters=i, init="k-means++")
kmeans.fit(df)
# Out:
# KMeans(n_clusters=10)

# %%
labels = kmeans.labels_
labels
# Out:
# array([3, 2, 4, ..., 0, 3, 3], shape=(9873,), dtype=int32)

# %%
labels[:20]
# Out:
# array([3, 2, 4, 5, 0, 8, 7, 1, 8, 2, 7, 3, 4, 5, 0, 9, 3, 3, 9, 8],
#       dtype=int32)

# %%
df["cluster"] = kmeans.labels_
df.head()
# Out:
#    Hours Studied  Previous Scores  Extracurricular Activities  Sleep Hours  \
# 0       0.775566         1.706168                           1     1.454025
# 1      -0.383205         0.724912                           0    -1.491315
# 2       1.161822        -1.064438                           1     0.275889
# 3       0.003052        -1.006717                           1    -0.902247
# 4       0.775566         0.320865                           0     0.864957
#
#    Sample Question Papers Practiced  Performance Index  cluster
# 0                         -1.249715           1.862979        3
# 1                         -0.900925           0.509348        2
# 2                         -0.900925          -0.531907        4
# 3                         -0.900925          -1.000471        5
# 4                          0.145444           0.561411        0

# %%
from sklearn.metrics import silhouette_score
print(silhouette_score(df,labels))
# Out:
# 0.39739946380602487
