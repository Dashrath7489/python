# %%
x = input("Enter the value: ")
print(x)
print(type(x))
# Out:
# hello Dashrath
# <class 'str'>

# %%
y = float(input("Enter the number"))

print(y)
print(type(y))
# Out:
# 7.8
# <class 'float'>

# %%
y = complex(input("Enter the value: "))
print(y)
print(type(y))
# Out:
# (5+2j)
# <class 'complex'>

# %%
x = 568
y = 345
sum = x+y
print(sum)
# Out:
# 913

# %%
Div = y/x
print(Div)
print(int(Div))
# Out:
# 0.6073943661971831
# 0

# %%
x = 48
print(x)
print(type(x))
y = str(x)
print(y)
print(type(y))
# Out:
# 48
# <class 'int'>
# 48
# <class 'str'>
