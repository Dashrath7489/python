# %%
# 1. Check if a given number is positive.

n = int(input("Enter the number: "))

if n>=0:
    print("positive")
else:
    print("not positive")
# Out:
# positive

# %%
# 2. Check if a given number is even.

n = int(input("enter the number: "))

if n % 2 == 0:
    print("even")

else:
    print("odd")
# Out:
# even

# %%
# 3. Check if a given number is a multiple of 5.

n = int(input("enter the Number: "))

if n % 5 == 0:
    print("yes")
else:
    print("not")
# Out:
# yes

# %%
# 4. Check if a given string is empty.

x = input("Enter the string: ")

if len(x) == 0:
    print("empty")

else:
    print("not empty")
# Out:
# not empty

# %%
# 5. Check if a given year is a leap year

year = int(input("enter the year: "))

if (year % 4 == 0) and (year % 100 != 0 or year % 400 == 0 ):
    print("leap")

else:
    print("not leap")
# Out:
# not leap

# %%
# 6. Check if a given character is a vowel.

chr = input("the character is vowel: ")

if chr in ["a","e","i","o","u"]:
    print(chr,"is cheracter is vowel ")
else:
    print(chr,"is not vowel")
# Out:
# g is not vowel

# %%
# 7. Check if a given number is between 1 and 10 (inclusive)

num = int(input("Enter the number: "))

if num>0 and num<11:
    print("given number is between 1 and 10")

else:
    print("given number is Not between 1 and 10")
# Out:
# given number is Not between 1 and 10

# %%
# 8. Check if a given string is a palindrome.

str = input()

if str[0::] == str[::-1]:
    print("palindrom")
else:
    print("Not palindrom")
# Out:
# palindrom

# %%
# 9. Check if a given number is a prime number.

n = int(input("Enter the number: "))

for i in range

# %%
# 10. Check if a given string is a pangram.

s = "qwertyuiopasdfghlzxcvnm"
p = input().lower()

for i in s:
    if i not in p:
        print("it is not pangram")
        break
else:
    print("pangram")
# Out:
# pangram

# %%
# 11. Check if a given list is empty

a = []

if len(a) == 0 :
    print("list is empty")
else:
    print("list is not empty")
# Out:
# list is empty

# %%
# 12. Check if a given number is divisible by both 2 and 3.

n = int(input("Enter the number: "))

if n % 2 ==0 and n % 3 == 0:
    print("number is devisible by both")
else:
    print("number is not divisible by both")
# Out:
# number is devisible by both

# %%
# 13. Check if a given string contains only digits.

str = input()

if

# %%
# 14. Check if a given number is a perfect square.

num = int(input("Enter the number: "))

root = int(num ** 0.5)

if num<0:
    print("not  a perfect square")

elif root * root == num:
    print("number is perfect square")

else:
    print("not a perfect squere", num)
# Out:
# number is perfect square

# %%
# 15. Check if a given string starts with a capital letter. 

str = input()

if str[0].upper() == True:
    print("yes starting word is capital")
else:
    print("starting word is not capital ")
# Out:
# starting word is not capital

# %%
# 16. Check if a given list contains a specific element. 

list1 = [1,4,5,6]

n = int(input("Enter the element to be checked: "))

if n in list1:
    print("specific element")

else:
    print("Not a specific element")
# Out:
# Not a specific element

# %%
# 17. Check if a given number is negative or zero.

n = int(input("Enter the number: "))

if n < 0:
    print("negative", n)
elif n == 0:
    print("number is Zero", n)

else:
    print("number is positive")
# Out:
# number is Zero 0

# %%
# 18. Check if a given string is alphanumeric. 
str = input()
if str.isalnum():
    print("string is alphanumeric")
else:
    print("string is not alphanumeric")
# Out:
# string is not alphanumeric

# %%
# 19. Check if a given year is a leap year and divisible by 100. 

year = int(input())

if year % 4 == 0 and (year % 100 != 0 or year % 400 == 0 ):
    if year % 100 == 0:
        print("leap year and divisible by 100 ")
    else:
        print("leap year but not divisible by 100")
else:
    print("not leap year")
# Out:
# leap year and divisible by 100

# %%
#20. Check if a given list is sorted in ascending order.
li = [1,3,4,5,6]
# li = [12,3,5,16,13,18]
li2 =sorted(li)

if li == li2:
    print("list is sorted")
else:
    print("not sorted")
# Out:
# list is sorted

# %%
#21. Check if a given string is a palindrome ignoring spaces

# %%
# 22. Check if a given number is a Fibonacci number.

# %%
#
