# %% [markdown]
# # set()

# %%
a = {1,2,3,4,5}
print(a)
type(a)
# Out:
# {1, 2, 3, 4, 5}
# set

# %%
b = {1,2,3,4,4,5}
print(b)
# Out:
# {1, 2, 3, 4, 5}

# %%
b = {1,2,3,"dash",1,4,6}
print(b)
# Out:
# {1, 2, 3, 4, 6, 'dash'}

# %%
b = set()
b.add(2)
print(b)
# Out:
# {2}

# %%
c = {2,4}
c.update([2,3])
print(c)
# Out:
# {2, 3, 4}
