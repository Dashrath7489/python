# %% [markdown]
# # tuple

# %%
t = (1,3,4,5)
print(type(t))
print(len(t))
# Out:
# <class 'tuple'>
# 4

# %%
tup2 = tuple((234,"das","hello",34,54))
print(tup2)
print(type(tup2))
print(len(tup2))
# Out:
# (234, 'das', 'hello', 34, 54)
# <class 'tuple'>
# 5

# %%
a =20,30
print(a)
# Out:
# (20, 30)

# %%
a,b,*c = 10,20 ,42,56,54,32

print(a)
print(b)
print(c)
# Out:
# 10
# 20
# [42, 56, 54, 32]

# %%
a = (43,)
type(a)
# Out:
# tuple
