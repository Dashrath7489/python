# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("samuelcortinhas/apples-or-tomatoes-image-classification")

print("Path to dataset files:", path)
# Out:
# Using Colab cache for faster access to the 'apples-or-tomatoes-image-classification' dataset.
# Path to dataset files: /kaggle/input/apples-or-tomatoes-image-classification

# %%
import os
import tensorflow as tf
DATASET_DIR = path
IMAGE_SIZE = (100,100)
BATCH_SIZE = 32
SEED = 123
LABEL_MODE_BINARY = "binary"
train_dir = os.path.join(DATASET_DIR,"train")
test_dir = os.path.join(DATASET_DIR,"test")

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    image_size = IMAGE_SIZE,
    batch_size = BATCH_SIZE,
    label_mode = LABEL_MODE_BINARY,
    seed = SEED,
    shuffle = True
)
# Out:
# Found 294 files belonging to 2 classes.

# %%
test_ds = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    image_size = IMAGE_SIZE,
    batch_size = BATCH_SIZE,
    label_mode = LABEL_MODE_BINARY,
    seed = 123,
    shuffle = False
)
# Out:
# Found 97 files belonging to 2 classes.

# %%
print(len(train_ds))
print(len(test_ds))
# Out:
# 10
# 4

# %%
classes = train_ds.class_names
print("class names:",classes)
# Out:
# class names: ['apples', 'tomatoes']

# %%
1
# Out:
# 1

# %%
def normlization(image,lable):
    image = tf.cast(image/255. ,tf.float32)
    return image, lable

# %%
train_ds = train_ds.map(normlization)
test_ds = test_ds.map(normlization)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D,MaxPooling2D,Flatten

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3,3),padding="valid",activation="relu", input_shape = (100,100,3)))
model.add(MaxPooling2D(pool_size=(2,2), strides=2, padding="valid"))
model.add(Conv2D(64,kernel_size=(3,3),padding = "valid",activation= "relu"))
model.add(MaxPooling2D(pool_size=(2,2), strides=2, padding="valid"))
model.add(Conv2D(128,kernel_size=(3,3),padding = "valid",activation= "relu"))
model.add(MaxPooling2D(pool_size=(2,2), strides=2, padding="valid"))
model.add(Flatten())
model.add(Dense(128,activation="relu"))
model.add(Dense(64,activation="relu"))
model.add(Dense(1, activation="sigmoid"))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 98, 98, 32)     │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 49, 49, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 47, 47, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 23, 23, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 21, 21, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 10, 10, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 12800)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     1,638,528 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,740,097 (6.64 MB)
#  Trainable params: 1,740,097 (6.64 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(optimizer="adam", loss="binary_crossentropy",metrics=["accuracy"])

# %%
history = model.fit(train_ds,validation_data=(test_ds),epochs=30)
# Out:
# Epoch 1/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 435ms/step - accuracy: 0.4762 - loss: 0.7162 - val_accuracy: 0.4948 - val_loss: 0.6909
# Epoch 2/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.6156 - loss: 0.6832 - val_accuracy: 0.5567 - val_loss: 0.6758
# Epoch 3/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.5578 - loss: 0.6777 - val_accuracy: 0.7320 - val_loss: 0.6557
# Epoch 4/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.6905 - loss: 0.6403 - val_accuracy: 0.7010 - val_loss: 0.6040
# Epoch 5/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7041 - loss: 0.6036 - val_accuracy: 0.7113 - val_loss: 0.5664
# Epoch 6/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7347 - loss: 0.5535 - val_accuracy: 0.6495 - val_loss: 0.6397
# Epoch 7/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.6871 - loss: 0.6164 - val_accuracy: 0.7010 - val_loss: 0.6015
# Epoch 8/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7347 - loss: 0.5408 - val_accuracy: 0.7113 - val_loss: 0.5455
# Epoch 9/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.7755 - loss: 0.4877 - val_accuracy: 0.7320 - val_loss: 0.5582
# Epoch 10/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7075 - loss: 0.5426 - val_accuracy: 0.6701 - val_loss: 0.5712
# Epoch 11/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7245 - loss: 0.5503 - val_accuracy: 0.7010 - val_loss: 0.5708
# Epoch 12/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.7755 - loss: 0.4740 - val_accuracy: 0.7423 - val_loss: 0.5084
# Epoch 13/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.8469 - loss: 0.3948 - val_accuracy: 0.7423 - val_loss: 0.4956
# Epoch 14/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.8878 - loss: 0.3507 - val_accuracy: 0.7732 - val_loss: 0.4923
# Epoch 15/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8844 - loss: 0.3038 - val_accuracy: 0.7629 - val_loss: 0.5507
# Epoch 16/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 59ms/step - accuracy: 0.8946 - loss: 0.2459 - val_accuracy: 0.7526 - val_loss: 0.6030
# Epoch 17/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9150 - loss: 0.2458 - val_accuracy: 0.7113 - val_loss: 0.6540
# Epoch 18/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - accuracy: 0.9286 - loss: 0.2073 - val_accuracy: 0.7010 - val_loss: 0.8789
# Epoch 19/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9422 - loss: 0.1637 - val_accuracy: 0.7526 - val_loss: 0.6688
# Epoch 20/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - accuracy: 0.9796 - loss: 0.1019 - val_accuracy: 0.7216 - val_loss: 0.5998
# Epoch 21/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - accuracy: 0.9830 - loss: 0.0698 - val_accuracy: 0.7629 - val_loss: 0.6831
# Epoch 22/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9932 - loss: 0.0373 - val_accuracy: 0.7320 - val_loss: 0.9482
# Epoch 23/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9864 - loss: 0.0356 - val_accuracy: 0.7526 - val_loss: 0.8087
# Epoch 24/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9524 - loss: 0.1363 - val_accuracy: 0.6186 - val_loss: 1.3148
# Epoch 25/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9456 - loss: 0.1489 - val_accuracy: 0.7526 - val_loss: 0.8470
# Epoch 26/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9728 - loss: 0.0830 - val_accuracy: 0.7526 - val_loss: 0.6800
# Epoch 27/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9932 - loss: 0.0284 - val_accuracy: 0.7629 - val_loss: 0.8822
# Epoch 28/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0160 - val_accuracy: 0.7423 - val_loss: 0.9393
# Epoch 29/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 0.0081 - val_accuracy: 0.7526 - val_loss: 0.9751
# Epoch 30/30
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.7526 - val_loss: 1.0953

# %%
model.save("AppleTomato.h5")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 model.save("AppleTomato.h5")
#
# NameError: name 'model' is not defined

# %%
import matplotlib.pyplot as plt
plt.plot(history.history["accuracy"], label = "accuracy")
plt.plot(history.history["val_accuracy"], label = "val_accuracy")
plt.legend()
plt.show()

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.2)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load image
img = cv2.imread(r"apple.jpg")

# ✅ FIX: check if image loaded
if img is None:
    print("Error: Image not found. Check file path.")
else:
    # Resize to model input size
    img = cv2.resize(img, (100, 100))

    # Normalize (VERY IMPORTANT)
    img = img / 255.0

    # Reshape
    img = img.reshape(1, 100, 100, 3)

    # Prediction
    result = model.predict(img)

    print("Raw Output:", result)

    plt.imshow(img[0])
    plt.show()

    # Convert to class
    if result[0][0] > 0.5:
        print("Prediction: Tomato")
    else:
        print("Prediction: Apple")
# Out:
# Error: Image not found. Check file path.

# %%
import cv2
test_img1 = cv2.imread(r"apple.jpg")

# %%
test_img1 = cv2.resize(test_img1,(100,100))

# %%
test_img1_resized = None

# ✅ FIX: check before resize
if test_img1 is None:
    print("Error: Image not loaded. Check path.")
else:
    test_img1_resized = cv2.resize(test_img1, IMAGE_SIZE)
    test_input1 = test_img1_resized / 255.0
    test_img1_resized = test_img1_resized.reshape(1, IMAGE_SIZE[0], IMAGE_SIZE[1], 3)
