# %% [markdown]
# # FileHandling

# %%
file = open("Dashrath.txt",'w')
file.write("I'm your data science student")
file.close()

# %%
aj = open("ajit.txt","r")
aj.read()
# Out:
# "Ajit Pawar was an Indian politician in Maharashtra. The state's longest-serving Deputy Chief Minister until his death in January 2026, he held the office for six terms under various governments including the cabinets of Prithviraj Chavan, Devendra Fadnavis, Uddhav Thackeray, and Eknath Shinde"

# %%
aj = open("ajit.txt","w")
aj.write("Ajit Pawars grandparents were Govindrao and Sharda Pawar.[6][7] Govindrao was associated with worker cooperatives in Baramati, while Sharda managed the family farm.[6] In 1938, she was elected to the Pune local board.[7] The couple had eleven children, including seven sons and four daughters;[7] one of their sons, named Sharad Pawar, later became the president of the Nationalist Congress Party (NCP) and a four-time chief minister of Maharashtra.[6]")
aj.close()

# %%
aj = open("ajit.txt","a")
aj.write("Later, he was elected to the Maharashtra Legislative Assembly seven times from the Baramati Assembly constituency. He first won in a 1991 by-election and subsequently retained it for five consecutive terms in 1995, 1999, 2004, 2009, and 2014.")
aj.close()

# %%
with open("Dashrath.txt","w") as file:
    file.write("""Sing Out Loud Children’s Songs
LYRICS:
TWINKLE, TWINKLE, LITTLE STAR
Twinkle, twinkle, little star, how I wonder what you are. Up above the world so high,
like a diamond in the sky. Twinkle, twinkle, little star, how I wonder what you are.
When the blazing sun is set, and the grass with dew is wet. Then you show your little
light, twinkle, twinkle all the night. Twinkle, twinkle little star, how I wonder what you
are.
Then the traveler in the dark thanks you for your tiny spark. How could he see where to
go if you did not twinkle so? Twinkle, twinkle little star, how I wonder what you are.
As your bright and tiny spark lights the traveler in the dark, though I know not what you
are, twinkle, twinkle, little star. Twinkle, twinkle, little star, how I wonder what you are.""")
