# %%
# 1. Write a Python script to sort (ascending and descending) a dictionary by value.

lst = {"a":20,"b":7,"c":9}
dict_item = list(lst.items())
print(dict_item[0][1])
for i in range(len(dict_item)):
    for j in range(i + 1, len(dict_item)):
        if dict_item[i][1] > dict_item[j][1]:
            dict_item[j],dict_item[i] = dict_item[i],dict_item[j]
print(dict_item)

# dic = {"a": 3,"b":2,"c":4,"d":1}
# dic = {"a": 3, "b": 2, "c": 4, "d": 1}
# # Ascending order
# sorted_asc = dict(sorted(dic.items(), key=lambda item: item[1]))
# # Descending order
# sorted_desc = dict(sorted(dic.items(), key=lambda item: item[1], reverse=True))
# print("Original Dictionary:", dic)
# print("Sorted Dictionary in Ascending Order:", sorted_asc)
# print("Sorted Dictionary in Descending Order:", sorted_desc)
# Out:
# Original Dictionary: {'a': 3, 'b': 2, 'c': 4, 'd': 1}
# Sorted Dictionary in Ascending Order: {'d': 1, 'b': 2, 'a': 3, 'c': 4}
# Sorted Dictionary in Descending Order: {'c': 4, 'a': 3, 'b': 2, 'd': 1}

# %%
# 2. Write a Python script to add a key to a dictionary.
# Sample Dictionary : {0: 10, 1: 20}
# Expected Result : {0: 10, 1: 20, 2: 30}

dic1 = {0:10,1:20}
dic2 = {2:30}

dic1.update(dic2)
print(dic1)
# Out:
# {0: 10, 1: 20, 2: 30}

# %%
# 3. Write a Python script to concatenate the following dictionaries to create a new
# one.
# Sample Dictionary :
# dic1={1:10, 2:20}
# dic2={3:30, 4:40}
# dic3={5:50,6:60}
# Expected Result : {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

dic1={1:10,2:20}
dic2={3:30,4:40}
dic3={5:50,6:60}

dic1.update(dic2)
dic1.update(dic3)
print(dic1)
# Out:
# {1: 10, 2: 20, 3: 30, 4: 40, 5: 50, 6: 60}

# %%
# 4. Write a Python script to check whether a given key already exists in a dictionary.
dic = {0:10,1:20,2:30}
key = 2
if key in dic:
    print("True")
else:
    print("False")
# Out:
# True

# %%
# 5. Write a Python script to generate and print a dictionary that contains a number
# (between 1 and n) in the form (x, x*x).
# Sample Dictionary ( n = 5) :
# Expected Output : {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}

dic = {}

for key in range(1,5):
    dic[key] = key*key
print(dic)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16}

# %%
# 6. Write a Python program to sum all the items in a dictionary.

sum = 0
dic1 = {1: 1, 2: 4, 3: 9, 4: 16}

for key,Value in dic1.items():
    sum+=Value
print(sum)
# Out:
# 30

# %%
# 7. Write a Python program to get the maximum and minimum values of dictionary.
dic1 = {1: 1, 2: 4, 3: 9, 4: 16}

mi = dic1[key]
maz = dic1[key]

for key,Value in dic1.items():
    
    if Value < mi:
        mi = Value
    if Value > maz:
        maz = Value
print(mi,maz)
# Out:
# 1 16

# %%
# 8. Write a Python program to combine two dictionary by adding values forcommon keys.
# d1 = {'a': 100, 'b': 200, 'c':300}
# d2 = {'a': 300, 'b': 200, 'd':400}
# Sample output: Counter({'a': 400, 'b': 400, 'd': 400, 'c': 300})

d1 = {"a":100,"b":200,"c":300}
d2 = {"a":200,"b":400,"c":500}

for i in d2:
    if i in d1:
        d1[i]+=d2[i]
    else:
        d1[i] = d2[i]
print(d1)
# Out:
# {'a': 300, 'b': 600, 'c': 800}

# %%
# 9. Write a Python program to print all distinct values in a dictionary.
# Sample Data : [{"V":"S001"}, {"V": "S002"}, {"VI": "S001"}, {"VI": "S005"},{"VII":"S005"}, {"V":"S009"},{"VIII":"S007"}]
# Expected Output : Unique Values: {'S005', 'S002', 'S007', 'S001', 'S009'}

Sample_Data = [{"V":"S001"}, {"V": "S002"}, {"VI": "S001"}, {"VI": "S005"},{"VII":"S005"}, {"V":"S009"},{"VIII":"S007"}]

s = set()
for i in Sample_Data:
    for key,Value in i.items():
        s.add(Value)
print(s)
# Out:
# {'S002', 'S007', 'S009', 'S001', 'S005'}

# %%
# 10. Write a Python program to create and display all combinations of letters,selecting each letter from a different key in a dictionary.
# Sample data : {'1':['a','b'], '2':['c','d']}
# Expected Output:
# ac
# ad
# bc
# bd

d1 = {'1':['a','b'], '2':['c','d']}
for i in d1['1']:
    for j in d1['2']:
        print(i+j)
# Out:
# ac
# ad
# bc
# bd

# %%
x = ['a','b']
y = ['c','d']

for i in x:
    for j in y:
        print(i+j)
# Out:
# ac
# ad
# bc
# bd

# %%
# 11. Write a Python program to combine values in a list of dictionaries.
# Sample data: [{'item': 'item1', 'amount': 400}, {'item': 'item2', 'amount': 300},
# {'item': 'item1', 'amount': 750}]
# Expected Output: Counter({'item1': 1150, 'item2': 300})

sample_data = [{'item': 'item1', 'amount': 400}, {'item': 'item2', 'amount': 300},{'item': 'item1', 'amount': 750}]

new_dic = {}

for i in sample_data:
    item = i["item"]
    amount = i["amount"]

    if item in new_dic:
        new_dic[item] += amount
    else:
        new_dic[item] = amount

print(new_dic)
# Out:
# {'item1': 1150, 'item2': 300}

# %%
# 12. Write a Python program to create a dictionary from a string.
# Note: Track the count of the letters from the string.
# Sample string : 'google'
# Expected output: {'g': 2, 'o': 2, 'r': 2, 'e': 1, 'l': 1}

dic = "google"
d = {}

for i in dic:
    if i in d:
        d[i] += 1
    else:
        d[i] = 1
print(d)
# Out:
# {'g': 2, 'o': 2, 'l': 1, 'e': 1}

# %%
st = "dashrath radha nirmal dashrath shyam nirmal"

d = {}

rep = st.split(" ")
for i in rep:
    if i in d:
        d[i] += 1
    else:
        d[i] = 1

print(d)
# Out:
# {'dashrath': 2, 'radha': 1, 'nirmal': 2, 'shyam': 1}

# %%
# 13. Write a Python program to get the top three items in a shop.
# Sample data: {'item1': 45.50, 'item2':35, 'item3': 41.30, 'item4':55, 'item5': 24}
# Expected Output:
# item4 55
# item1 45.5
# item3 41.3
data = {'item1': 45.50, 'item2':35, 'item3': 41.30, 'item4':55, 'item5': 24}
dict_item = list(data.items())
# print(dict_item[0][1])
for i in range(len(dict_item)):
    for j in range(i + 1, len(dict_item)):
        if dict_item[i][1] < dict_item[j][1]:
            dict_item[j],dict_item[i] = dict_item[i],dict_item[j]
for i in range(0,len(dict_item)):
    if i<3:
        print(dict_item[i])
# Out:
# ('item4', 55)
# ('item1', 45.5)
# ('item3', 41.3)

# %%
# 14. Write a Python program to sort Counter by value.
# Sample data : {'Math':81, 'Physics':83, 'Chemistry':87}

# lst = {"a":20,"b":7,"c":9}
data = {'Math':81, 'Physics':83, 'Chemistry':87}
dict_item = list(data.items())
# print(dict_item[0][1])
for i in range(len(dict_item)):
    for j in range(i + 1, len(dict_item)):
        if dict_item[i][1] < dict_item[j][1]:
            dict_item[j],dict_item[i] = dict_item[i],dict_item[j]
print(dict_item)
# Out:
# [('Chemistry', 87), ('Physics', 83), ('Math', 81)]

# %%
# 15. Write a Python program to create a dictionary of keys x, y, and z where each
# key has as value a list from 11-20, 21-30, and 31-40 respectively. Access the fifth
# value of each key from the dictionary.
# {'x': [11, 12, 13, 14, 15, 16, 17, 18, 19],
# 'y': [21, 22, 23, 24, 25, 26, 27, 28, 29],
# 'z': [31, 32, 33, 34, 35, 36, 37, 38, 39]}
# 15
# 25
# 35
# x has value [11, 12, 13, 14, 15, 16, 17, 18, 19]
# y has value [21, 22, 23, 24, 25, 26, 27, 28, 29]
# z has value [31, 32, 33, 34, 35, 36, 37, 38, 39]

d = {}
d['x'] = list(range(11,20))
d['y'] = list(range(21,30))
d['z'] = list(range(31,40))
print(d['x'][4])
print(d['y'][4])
print(d['z'][4])
# Out:
# 15
# 25
# 35

# %%
# 16.WriteaPythonprogramtodropemptyitemsfromagivendictionary.
# OriginalDictionary:
# {'c1': 'Red', 'c2': 'Green', 'c3':None}
# NewDictionaryafterdroppingemptyitems:
# {'c1': 'Red', 'c2': 'Green'}

d = {'c1': 'Red', 'c2': 'Green', 'c3':None}
new_d = {}
for key,Value in d.items():
    if Value is not None:
        new_d[key] = Value
print(new_d)
# Out:
# {'c1': 'Red', 'c2': 'Green'}

# %%
# 17.WriteaPythonprogramtoverifythatallvaluesinadictionaryarethesame.
# OriginalDictionary:
# {'CierraVega':12, 'AldenCantrell':12, 'KierraGentry':12, 'PierreCox':12}
# Checkallare12inthedictionary.
# True
# Checkallare10inthedictionary.
# False

d = {}
d['CierraVega'] = 12
d['AldenCantrell'] = 12
d['KierraGentry'] = 12
d['PierreCox'] = 12

# Check all are 12 in the dictionary.
all_values_same = all(value == 12 for value in d.values())
print(all_values_same)

# Check all are 10 in the dictionary.
all_values_same = all(value == 10 for value in d.values())
print(all_values_same)
# Out:
# True
# False

# %%
# 18.WriteaPythonprogramtocreateadictionarygroupingasequenceof
# key-valuepairsintoadictionaryof lists.
# Original list:
# [('yellow',1),('blue',2),('yellow',3),('blue',4),('red',1)]
# Groupingasequenceofkey-valuepairsintoadictionaryof lists:
# {'yellow': [1,3], 'blue': [2,4], 'red': [1]}

d = {}
pairs = [('yellow',1),('blue',2),('yellow',3),('blue',4),('red',1)]
for key,Value in pairs:
    if key in d:
        d[key].append(Value)
    else:
        d[key] = [Value]
print(d)
# Out:
# {'yellow': [1, 3], 'blue': [2, 4], 'red': [1]}

# %%
# 19. Write a Python program to split a given dictionary of lists into lists of
# dictionaries.
# Original dictionary of lists:
# {'Science': [88, 89, 62, 95], 'Language': [77, 78, 84, 80]}
# Split said dictionary of lists into list of dictionaries:
# [{'Science': 88, 'Language': 77}, {'Science': 89, 'Language': 78}, {'Science': 62,
# 'Language': 84}, {'Science': 95, 'Language': 80}]
d = {'Science': [88, 89, 62, 95], 'Language': [77, 78, 84, 80]}
result = []
for i in range(len(d['Science'])):
    result.append({key: d[key][i] for key in d.keys()})
print(result)
# Out:
# [{'Science': 88, 'Language': 77}, {'Science': 89, 'Language': 78}, {'Science': 62, 'Language': 84}, {'Science': 95, 'Language': 80}]

# %%
# 20. Write a Python program to extract a list of values from a given list of
# dictionaries.
# Original Dictionary:
# [{'Math': 90, 'Science': 92}, {'Math': 89, 'Science': 94}, {'Math': 92, 'Science': 88}]
# Extract a list of values from said list of dictionaries where subject = Science
# [92, 94, 88]
# Original Dictionary:
# [{'Math': 90, 'Science': 92}, {'Math': 89, 'Science': 94}, {'Math': 92, 'Science': 88}]
# Extract a list of values from said list of dictionaries where subject = Math
# [90, 89, 92]

original_dict = [{'Math': 90, 'Science': 92}, {'Math': 89, 'Science': 94}, {'Math': 92, 'Science': 88}]
science_values = [d['Science'] for d in original_dict]
math_values = [d['Math'] for d in original_dict]
print("Science values:", science_values)
# Out:
# Science values: [92, 94, 88]
