# %%
x = "python"
print(x)
# Out:
# python

# %%
try:
    x = "string"
    print(x)
except SyntaxError:
    print("please correct  your syntax")
# Out:
# string

# %%
n = 10
try:
    res = n / 0
except ZeroDivisionError:
    print("Can't be divided by zero!")
# Out:
# Can't be divided by zero!

# %%
try:
    x = int(input("Enter the value x: "))
    y = int(input("Enter the value y: "))

    div = x/y
    print(div)
except Exception as arg:
    print("type of error",arg)
else:
    print("Addition", x+y)

finally:
    print("this is always executable")
    print("Block of code successfully executed")
# Out:
# 0.42592592592592593
# Addition 77
# this is always executable
# Block of code succesfully executed

# %%
try:
    x = int(input("Enter the value x: "))
    y = int(input("Enter the value y: "))

    div = x/y
    print(div)
except Exception as arg:
    print("type of error",arg)
# else:
#     print("Addition", x+y)

finally:
    print("this is always executable")
    print("Block of code successfully executed")
# Out:
# 0.6071428571428571
# this is always executable
# Block of code successfully executed

# %%
try:

except IndentationError:
