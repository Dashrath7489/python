# %%
# Question 3: Problem: Extract all hashtags (words starting with #) from a tweet.
# Test String: "This is a #great day for #learning Python regex!"
import warnings
warnings.filterwarnings("ignore")

import re
string = "This is a #great day for #learning Python regex!"
pattern = "#\w+"
print(re.findall(pattern,string))
# Out:
# ['#great', '#learning']

# %%
# Question 4: Problem: Find all four-digit years in a string.
#  Test String: "The years 1999, 2005, and 2023 were significant."

s = "The years 1999, 2005, and 2023 were significant."
pattern = "\d+"
print(re.findall(pattern,s))
# Out:
# ['1999', '2005', '2023']

# %%
# Question 5: Problem: Extract all phone numbers in the format (XXX) XXX-XXXX.
# Test String: "Call us at (123) 456-7890 or (987) 654-3210.

# %%
# Question 6: Problem: Validate if a string is a valid IPv4 address. 
# Test String 1: "192.168.1.1"
# Test String 2: "256.0.0.1"

# %%
# Question 7: Problem: Replace all occurrences of "Python" (case-insensitive) with "Java". 
# Test String: "Python is fun. python is powerful. PYTHON is versatile."
