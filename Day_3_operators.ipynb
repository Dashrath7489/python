# %%
# Arithmatic operators

# Addition +
# substraction -
# Multiplication *
# Division /
# floor Division //
# explonention % 

a = 10
b = 20

print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
# Out:
# 30
# -10
# 200
# 0.5
# 0
# 10

# %%
# Assignment operator

# 1 Addition Assignment operator +=
# 2 Substraction asi -=
# 3 Multiplication assi *=
# 4 Division assi /=
# 5 Floor Division //=
# 6 modulus assi %=

a = 458

a += 10
print(a)
# Out:
# 468

# %%
b += 50
a
# Out:
# 18

# %%
a += b
a
# Out:
# 88

# %%
a%=b
print(a)
# Out:
# 18

# %%
# comparision operator
# 1 >,<,>=,<=,==,!=

a = 458
b = 348

print(a>b)
# Out:
# True

# %%
a = 458
b = 458

print(a>=b)
# Out:
# True

# %%
a = 458
b = 458

print(a<=b)
# Out:
# True

# %%
a = 458
b = 4580

print(a>=b)
# Out:
# False

# %%
a = 458
b = 458

print(a==b)
# Out:
# True

# %%
a = 458
b = 458

print(a!=b)
# Out:
# False

# %%
# logical operator
# AND
# OR
# NOT

# %%
a = 89
b = 45

print(a > b and b == a)
print(a > b and b <= a)
print(b < a and b >= a)
# Out:
# False
# True
# False

# %%
print(a > b or b == a)
print(a > b or b <= a)
print(b < a or b >= a)
print(a < b or b == a)
# Out:
# True
# True
# True
# False

# %%
a = True
b = False

print(not a)
print(not b)
# Out:
# False
# True

# %%
x = 12
print(x)

bin_x = bin(x)
print(bin_x)
# Out:
# 12
# 0b1100

# %%
print(0b1000)
# Out:
# 8

# %%
a = 12
b = 14

print(bin(a))
print(bin(b))
# Out:
# 0b1100
# 0b1110

# %%
print(a&b)
print(a | b)
# Out:
# 12
# 14

# %%
n = bin(int(input("enter the value: ")))
print(n)
# Out:
# 0b1100

# %%
# XOR

u = 23
v = 15

print(bin(u))
print(bin(v))
print(u ^ v)
# Out:
# 0b10111
# 0b1111
# 24

# %%
print(bin(24))
# Out:
# 0b11000

# %%
# left shift <<
# jab ham left shift karte hai yo "multiplication hota hai  formula hai x * 2^n "
# jab ham Right shift karte hai yo "Division hota hai  formula hai x / 2^n "



x = 8
y = 32
print(x<<2)
print(y>>3)
# Out:
# 32
# 4

# %%
x = 36
print(x<<2)
print(x>>2)
# Out:
# 144
# 9

# %%
# Nor

var = -36

print(~var)
# Out:
# 35

# %%
# assignment operator

x = "hadup"

print(len(x))
# Out:
# 5

# %%
# identity operator

x = 20
y = 20

print(id(x))
print(id(y))
print(x is y)
# Out:
# 140703243631640
# 140703243631640
# True

# %%
# Advance datatype me value change hoti hai number or variable me nhi

u = [1,2,3]
v = [1,2,3]

print(id(u))
print(id(x))
print(u == v) # Check the value similar hai ki nhi
print(u is v) # ye id chek karta hai
# Out:
# 1782558377664
# 140703243631640
# False

# %%
u = [1,2,3]
v = [1,2,3]
