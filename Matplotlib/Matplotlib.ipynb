# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\VICTUS\OneDrive\Desktop\Grow Stack Data Science\Datasets\cleaned_penguin_df.csv", 
                 index_col = "Unnamed: 0")
df.head()
# Out:
#    id species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0   0  Adelie  Torgersen           39.10           18.7              181.0
# 1   1  Adelie  Torgersen           39.50           17.4              186.0
# 2   2  Adelie  Torgersen           40.30           18.0              195.0
# 3   3  Adelie  Torgersen           44.45           17.3              197.0
# 4   4  Adelie  Torgersen           36.70           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3       4050.0    male  2007
# 4       3450.0  female  2007

# %%
df.isnull().sum()
# Out:
# id                   0
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# year                 0
# dtype: int64

# %%
plt.plot(df["bill_length_mm"])
plt.show()

# %%
plt.figure(figsize = (6,2))
plt.plot(df["bill_length_mm"])
plt.show()

# %%
plt.figure(figsize= (6,2))
plt.plot(df["bill_length_mm"],label = "bill_length",color= "red")
plt.plot(df["flipper_length_mm"], label = "flipper_length", color="black")
plt.title("line chart")
plt.xlabel("x axis")
plt.ylabel("y axis")

plt.legend()
plt.show()

# %%
plt.figure(figsize= (8,6))
plt.plot(df["bill_length_mm"],marker = "*", ms = 5, mec = "r")
plt.show()

# %%
plt.figure(figsize= (6,3))
plt.bar(x = df["island"], height= df ["flipper_length_mm"],)
plt.xlabel("Island")
plt.ylabel("Flipper length")
plt.show()

# %%
import seaborn as sns

# %%
plt.figure(figsize= (6,3))
sns.barplot(x = df["island"] ,
            y =df["flipper_length_mm"] ,
            hue = df["island"])
plt.xlabel("Island")
plt.ylabel("flipper length")
plt.show()

# %%
plt.Figure(figsize= (6,2))
sns.lineplot(df["bill_length_mm"], lable = "bill_length")

# %%
plt.figure(figsize=(6,2))
plt.hist(df["flipper_length_mm"])
plt.show()

# %%
plt.figure(figsize=(6,2))
sns.histplot(df["flipper_length_mm"])
plt.show()

# %%
df["island"].value_counts()
# Out:
# island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %%
df["island"].value_counts().index
# Out:
# Index(['Biscoe', 'Dream', 'Torgersen'], dtype='str', name='island')

# %%
df["island"].value_counts().values
# Out:
# array([168, 124,  52])

# %%
plt.figure(figsize = (4,4))
plt.pie(x= df["island"].value_counts().values, labels= df["island"].value_counts().index , autopct = "%0.2f%%")

plt.legend()
plt.show()

# %%
sns.scatterplot (x = df["flipper_length_mm"], y = df["bill_length_mm"],hue = df["species"])
plt.grid()
plt.show()

# %%
plt.Figure(figsize= (5,2))
sns.boxplot(x=df["flipper_length_mm"])
plt.show()

# %%
plt.Figure(figsize= (5,2))
sns.boxenplot(x=df["flipper_length_mm"])
plt.show()

# %%
plt.Figure(figsize= (5,2))
sns.violinplot(x=df["flipper_length_mm"])
plt.show()
